# %%
import pandas as pd

# %%
df =pd.read_excel('D-F_1mg.xlsx')

# %%
cf =pd.read_excel('D-F_netmeds.xlsx')

# %%
gf =pd.read_excel('D-F_Pharmeasy.xlsx')

# %%
df
# Out:
#                       Product Name                     Marketer Name  \
# 0                  Dolo 650 Tablet                    Micro Labs Ltd
# 1            Duphaston 10mg Tablet                            Abbott
# 2                Derobin  Ointment                           USV Ltd
# 3                  Doxinate Tablet       Maneesh Pharmaceuticals Ltd
# 4                 Defcort 6 Tablet  Macleods Pharmaceuticals Pvt Ltd
# ...                            ...                               ...
# 23379          Feburox 40mg Tablet     Trireme Life Sciences Pvt Ltd
# 23380          Freshpin Toothpaste              Pinarc Life Sciences
# 23381  Filnac P 100mg/325mg Tablet         Filant (India) Healthcare
# 23382           Floxi 200mg Tablet        Mahawat Healthcare Pvt Ltd
# 23383        Flution-F Nasal Spray                Avilius Neutracare
#
#                                         Marketer Address  \
# 0         27, RACE COURSE ROAD, BANGALORE-560 001, INDIA
# ...

# %%
cf
# Out:
#                                     Medname     Quantity_and_Packform  \
# 0                    D 1000 Cal Tablet 10'S   10 Tablet(s) in a Strip
# 1                     D 500 Cal Tablet 10'S   10 Tablet(s) in a Strip
# 2        D Acne Foaming Face Wash Foam 60ml                      None
# 3                           D Acne Gel 10gm                      None
# 4                D Acne I 10mg Capsule 10'S  10 Capsule(s) in a Strip
# ...                                     ...                       ...
# 2902        Fytopenem 1000mg Injection 20ml                      None
# 2903         Fytopenem 500mg Injection 10ml                      None
# 2904  Fytopenem XP 1000/500mg Injection 1ml                      None
# 2905                Fyzen 0.5mg Tablet 10'S   10 Tablet(s) in a Strip
# 2906                      Fzhh 150mg Tablet    1 Tablet(s) in a Strip
#
#                               Manufacturer  \
# 0                   Eris Lifesciences Ltd
# ...

# %%
gf
# Out:
#                                medName                       manufacturer  \
# 0             Deflato 30mg Tablet 10's         SAG HEALTH SCIENCE PVT LTD
# 1      Deflato 6mg Strip Of 10 Tablets         SAG HEALTH SCIENCE PVT LTD
# 2            Deflavell 6mg Tablet 10's                          TMS INDIA
# 3                     Deflavik 6mg Tab             ANKARE PHARMACEUTICALS
# 4         Deflawal Strip Of 10 Tablets          ELDER PHARMACEUTICALS LTD
# ...                                ...                                ...
# 26329                  Fulsed Inj 10ml  RANBAXY LABORATORIES (SUN PHARMA)
# 26330                   Fulsed Inj 1ml  RANBAXY LABORATORIES (SUN PHARMA)
# 26331                   Fulsed Inj 5ml  RANBAXY LABORATORIES (SUN PHARMA)
# 26332                 Fulstop Syp 30ml        ADONIS LABORATORIES PVT LTD
# 26333              Fulstrch P Tab 10's                                NaN
#
#                                                    salts prescription_req  \
# ...

# %%
df.columns
# Out:
# Index(['Product Name', 'Marketer Name', 'Marketer Address',
#        'Prescription Required', 'MRP', 'Ingredients', 'Units in Pack',
#        'Pack Size', 'Unit of Measurement', 'Pack Form', 'Stock',
#        'Introduction', 'Uses', 'Benefits', 'How to Use', 'How medicine works',
#        'If you forget to take', 'Quick Tips', 'Side Effects',
#        'How to cope with side effects', 'Precaution', 'URL'],
#       dtype='object')

# %%
cf.columns
# Out:
# Index(['Medname', 'Quantity_and_Packform', 'Manufacturer', 'Composition',
#        'Discount Price', 'Sales Price'],
#       dtype='object')

# %%
gf.columns
# Out:
# Index(['medName', 'manufacturer', 'salts', 'prescription_req',
#        'pack_size_label', 'in_stock', 'selling_price', 'mrp', 'uses',
#        'precautions', 'directions', 'storage', 'side_effects', 'pageURL',
#        'Ingredients and benefits', 'Medical Description'],
#       dtype='object')

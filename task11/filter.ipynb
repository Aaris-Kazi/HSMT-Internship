# %%
import pandas as pd

# %%
df = pd.read_csv('chat.csv')

# %%
df
# Out:
#     Unnamed: 0                                          Questions
# 0            0                                   How old are you?
# 1            1  Are you experiencing any of the following prob...
# 2            2                 How long have you had throat pain?
# 3            3                       How bad is your throat pain?
# 4            4  Have you travelled in the last 15 days, inside...
# 5            5  Have you come in contact with anyone who trave...
# 6            6  Have you met or been in close contact with som...
# 7            7  Have you come in contact with anybody who has ...
# 8            8  Have you been to any gatherings of more than 5...
# 9            9   Do you wear a mask while you are outside or w...
# 10          10             Have you been diagnosed with Covid-19?
# 11          11     , can you tell me if you have been vaccinated?

# %%
sf = pd.read_csv('chat1.csv')

# %%
sf
# Out:
#     Unnamed: 0                                            Options
# 0            0  Below 18 years, 19 - 30 years, 31 - 40 years, ...
# 1            1  Tiredness, Throat Pain, Fever, Loss of Taste/S...
# 2            2    1 - 3 days, 3- 5 days, 5 -7 days, 7 - 14 days,
# 3            3                  Mild, Moderate, Severe, No pain,
# 4            4                                          Yes, No,
# 5            5                              Yes, No, Don't Know,
# 6            6                              Yes, No, Don't Know,
# 7            7                              Yes, No, Don't Know,
# 8            8                                          Yes, No,
# 9            9                               Yes, No, Sometimes,
# 10          10  currently Covid +ve, Recovered from Covid, Don...
# 11          11      Yes - both doses, Yes - but only 1 dose, No,

# %%
df['Options']= sf['Options'].values

# %%
df.to_csv('chat3.csv')

# %%
df
# Out:
#     Unnamed: 0                                          Questions  \
# 0            0                                   How old are you?
# 1            1  Are you experiencing any of the following prob...
# 2            2                 How long have you had throat pain?
# 3            3                       How bad is your throat pain?
# 4            4  Have you travelled in the last 15 days, inside...
# 5            5  Have you come in contact with anyone who trave...
# 6            6  Have you met or been in close contact with som...
# 7            7  Have you come in contact with anybody who has ...
# 8            8  Have you been to any gatherings of more than 5...
# 9            9   Do you wear a mask while you are outside or w...
# 10          10             Have you been diagnosed with Covid-19?
# 11          11     , can you tell me if you have been vaccinated?
#
#                                               Options
# ...

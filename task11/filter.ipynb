# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\aaris\\Desktop\\forinternship\\HSMT-Internship\\chat1.csv')

# %%
df
# Out:
#     Unnamed: 0                                          Questions
# 0            0                          Tell me, how old are you?
# 1            1  What irregularities in the size of the breast(...
# 2            2  Which of the following nipple issues did you n...
# 3            3  What kind of discharge, from the nipple, did y...
# 4            4  Did you notice any of these changes in your br...
# 5            5  During the breast exam, did you feel any lumps...
# 6            6  Are you noticing these lumps and nodules durin...
# 7            7                     Do you identify yourself as...
# 8            8                At what age did your periods start?
# 9            9                       Have you ever been pregnant?
# 10          10                     How many children do you have?
# 11          11    How old were you when you had your first child?
# 12          12  And how long did you breastfeed your child/chi...
# 13          13  Have you ever used oral contraceptives or been...
# 14          14                     Have you ever had a mammogram?
# 15          15                         Was your mammogram normal?
# 16          16  Have you undergone surgery to remove your uter...
# 17          17  Have you ever had any of the following breast ...
# 18          18  Has anyone in your immediate family been diagn...
# 19          19                            Do you consume alcohol?

# %%
sf = pd.read_csv('C:\\Users\\aaris\\Desktop\\forinternship\\HSMT-Internship\\chat.csv')

# %%
sf
# Out:
#     Unnamed: 0                                            Options
# 0            0  20 years & less, 21 to 30 years, 31 to 40 year...
# 1            1  Unequal breast size, Swelling, None of the abo...
# 2            2  Discharge, Cracked nipple, Inverted/Retracted ...
# 3            3  Bloody, Yellow and/or mucoid, Clear, Milky, No...
# 4            4  Dimpling, Redness, Cluster(s) of bulging veins...
# 5            5                                          Yes, No,
# 6            6                                          Yes, No,
# 7            7    Underweight, Normal weight, Overweight, Obese,
# 8            8  9 years old or lesser, From 10 to 15 year old,...
# 9            9                                           Yes, No
# 10          10  1-2 children, 3-4 children, More than 5 childr...
# 11          11                20 years & lesser, 20 to 35 years,
# 12          12  Less than 3 months, 3 to 6 months, 7 to 11 mon...
# 13          13                                          Yes, No,
# 14          14                                          Yes, No,
# 15          15          Yes, No, it was abnormal, I am not sure,
# 16          16  Uterus was removed, Ovaries were removed, Ovar...
# 17          17                                          Yes, No,
# 18          18                            Yes, No, I don't know,
# 19          19  Occasionally, Everyday(Atleast 1 drink/day), I...

# %%
df['Options']= sf['Options'].values

# %%
df.to_csv('chat3.csv')

# %%
df
# Out:
#     Unnamed: 0                                          Questions  \
# 0            0                          Tell me, how old are you?
# 1            1  What irregularities in the size of the breast(...
# 2            2  Which of the following nipple issues did you n...
# 3            3  What kind of discharge, from the nipple, did y...
# 4            4  Did you notice any of these changes in your br...
# 5            5  During the breast exam, did you feel any lumps...
# 6            6  Are you noticing these lumps and nodules durin...
# 7            7                     Do you identify yourself as...
# 8            8                At what age did your periods start?
# 9            9                       Have you ever been pregnant?
# 10          10                     How many children do you have?
# 11          11    How old were you when you had your first child?
# 12          12  And how long did you breastfeed your child/chi...
# 13          13  Have you ever used oral contraceptives or been...
# 14          14                     Have you ever had a mammogram?
# 15          15                         Was your mammogram normal?
# 16          16  Have you undergone surgery to remove your uter...
# 17          17  Have you ever had any of the following breast ...
# 18          18  Has anyone in your immediate family been diagn...
# 19          19                            Do you consume alcohol?
#
#                                               Options
# 0   20 years & less, 21 to 30 years, 31 to 40 year...
# 1   Unequal breast size, Swelling, None of the abo...
# 2   Discharge, Cracked nipple, Inverted/Retracted ...
# 3   Bloody, Yellow and/or mucoid, Clear, Milky, No...
# 4   Dimpling, Redness, Cluster(s) of bulging veins...
# 5                                           Yes, No,
# 6                                           Yes, No,
# 7     Underweight, Normal weight, Overweight, Obese,
# 8   9 years old or lesser, From 10 to 15 year old,...
# 9                                            Yes, No
# 10  1-2 children, 3-4 children, More than 5 childr...
# 11                20 years & lesser, 20 to 35 years,
# 12  Less than 3 months, 3 to 6 months, 7 to 11 mon...
# 13                                          Yes, No,
# 14                                          Yes, No,
# 15          Yes, No, it was abnormal, I am not sure,
# 16  Uterus was removed, Ovaries were removed, Ovar...
# 17                                          Yes, No,
# 18                            Yes, No, I don't know,
# 19  Occasionally, Everyday(Atleast 1 drink/day), I...

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\aaris\\Desktop\\forinternship\\HSMT-Internship\\chat1.csv')

# %%
df
# Out:
#     Unnamed: 0                                          Questions
# 0            0  I would like to know a bit more about you.😊How...
# 1            1                                         You are...
# 2            2  Have you ever been found to have high blood su...
# 3            3  Did your report point out any of these as abno...
# 4            4             How much was your last measured HBA1c?
# 5            5  As you said your blood sugars were found to be...
# 6            6               Have you experienced the following?
# 7            7  Do you experience excessive tiredness along wi...
# 8            8               Are these symptoms familiar to you?
# 9            9    Have you observed any of these skin conditions?
# 10          10  Coming to family history, have any of your blo...
# 11          11                                Do you generally...
# 12          12              Say, how would you describe yourself?
# 13          13                Do you set aside time for exercise?
# 14          14             Tell me a little about your lifestyle.
# 15          15  Have you been diagnosed with any of these cond...

# %%
sf = pd.read_csv('C:\\Users\\aaris\\Desktop\\forinternship\\HSMT-Internship\\chat.csv')

# %%
sf
# Out:
#     Unnamed: 0                                            Options
# 0            0  20 years and less, 21 to 30 years, 31 to 40 ye...
# 1            1                                     Female, Male,
# 2            2                                          Yes, No,
# 3            3  HbA1c, Blood sugars, Urine sugar +ve, I don't ...
# 4            4  HbA1c ≥9%, HbA1c 6.5% to 9%, HbA1c 5.9% - 6.4%...
# 5            5        Pre-diabetes, Diabetes, None of the above,
# 6            6  Frequent urination, Consistently thirsty, Freq...
# 7            7                                          Yes, No,
# 8            8  Tingling/burning sensation, Shoulder stiffness...
# 9            9  Skin tags, Skin thickening/darkening, None of ...
# 10          10                                          Yes, No,
# 11          11  Skip meals often, Eat sugary/fatty junk food, ...
# 12          12  I am underweight, I am at a healthy weight, I ...
# 13          13            No, Rarely, Weekends, Weekdays, Daily,
# 14          14  Stress, Drinking alcohol, Cigarette smoking, I...
# 15          15  Cholesterol issues, High blood pressure, PCOS ...

# %%
df['Options']= sf['Options'].values

# %%
df.to_csv('chat3.csv')

# %%
df
# Out:
#     Unnamed: 0                                          Questions  \
# 0            0  I would like to know a bit more about you.😊How...
# 1            1                                         You are...
# 2            2  Have you ever been found to have high blood su...
# 3            3  Did your report point out any of these as abno...
# 4            4             How much was your last measured HBA1c?
# 5            5  As you said your blood sugars were found to be...
# 6            6               Have you experienced the following?
# 7            7  Do you experience excessive tiredness along wi...
# 8            8               Are these symptoms familiar to you?
# 9            9    Have you observed any of these skin conditions?
# 10          10  Coming to family history, have any of your blo...
# 11          11                                Do you generally...
# 12          12              Say, how would you describe yourself?
# 13          13                Do you set aside time for exercise?
# 14          14             Tell me a little about your lifestyle.
# 15          15  Have you been diagnosed with any of these cond...
#
#                                               Options
# 0   20 years and less, 21 to 30 years, 31 to 40 ye...
# 1                                      Female, Male,
# 2                                           Yes, No,
# 3   HbA1c, Blood sugars, Urine sugar +ve, I don't ...
# 4   HbA1c ≥9%, HbA1c 6.5% to 9%, HbA1c 5.9% - 6.4%...
# 5         Pre-diabetes, Diabetes, None of the above,
# 6   Frequent urination, Consistently thirsty, Freq...
# 7                                           Yes, No,
# 8   Tingling/burning sensation, Shoulder stiffness...
# 9   Skin tags, Skin thickening/darkening, None of ...
# 10                                          Yes, No,
# 11  Skip meals often, Eat sugary/fatty junk food, ...
# 12  I am underweight, I am at a healthy weight, I ...
# 13            No, Rarely, Weekends, Weekdays, Daily,
# 14  Stress, Drinking alcohol, Cigarette smoking, I...
# 15  Cholesterol issues, High blood pressure, PCOS ...

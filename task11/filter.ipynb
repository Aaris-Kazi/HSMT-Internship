# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\aaris\\Desktop\\forinternship\\HSMT-Internship\\chat1.csv')

# %%
df
# Out:
#     Unnamed: 0                                          Questions
# 0            0                                   How old are you?
# 1            1                                         You are...
# 2            2                     Tell me, what brings you here?
# 3            3        Since when have you noticed weight gain? 🎯
# 4            4  Tell me, how many kilos have you gained over l...
# 5            5            I eat less but I keep gaining weight.""
# 6            6  Coming to menstrual cycles...How many days go ...
# 7            7  How many pads or tampons do you use per day du...
# 8            8                    Do you face any of these signs?
# 9            9            Have you checked for TSH and T4 levels?
# 10          10  Say, did your TSH and T4 report say something ...
# 11          11             Tell me a little about your lifestyle.
# 12          12  Do you know some conditions increase your risk...
# 13          13  Before you go, have you been diagnosed with ch...

# %%
sf = pd.read_csv('C:\\Users\\aaris\\Desktop\\forinternship\\HSMT-Internship\\chat.csv')

# %%
sf
# Out:
#     Unnamed: 0                                            Options
# 0            0  Less than 21 years, 21 - 49 years, 50 - 64 yea...
# 1            1                                     Female, Male,
# 2            2  Weight Gain, Hair Problems, Skin Problems, Tir...
# 3            3  Less than 3 months, 3 - 6 months, 6 - 11 month...
# 4            4  Less than 5 kgs, 6 - 10 kgs, 11 - 20 kgs, More...
# 5            5                                          Yes, No,
# 6            6  21 - 28 days, 28 - 35 days, < 21 days, > 35 da...
# 7            7              1 to 2, 3 to 4, 5 to 7, More than 7,
# 8            8  Feeling Cold Often, Observed Swelling (face/fe...
# 9            9                                          Yes, No,
# 10          10  Less than 3 months, Less than 5 kgs, 21 - 28 d...
# 11          11  Yes, Stress, Regular Exercise, Overeating, Dis...
# 12          12  Yes, Stress, I am a pregnant woman, Family his...
# 13          13  Yes, Stress, I am a pregnant woman, Diabetes, ...

# %%
df['Options']= sf['Options'].values

# %%
df.to_csv('chat3.csv')

# %%
df
# Out:
#     Unnamed: 0                                          Questions  \
# 0            0                                   How old are you?
# 1            1                                         You are...
# 2            2                     Tell me, what brings you here?
# 3            3        Since when have you noticed weight gain? 🎯
# 4            4  Tell me, how many kilos have you gained over l...
# 5            5            I eat less but I keep gaining weight.""
# 6            6  Coming to menstrual cycles...How many days go ...
# 7            7  How many pads or tampons do you use per day du...
# 8            8                    Do you face any of these signs?
# 9            9            Have you checked for TSH and T4 levels?
# 10          10  Say, did your TSH and T4 report say something ...
# 11          11             Tell me a little about your lifestyle.
# 12          12  Do you know some conditions increase your risk...
# 13          13  Before you go, have you been diagnosed with ch...
#
#                                               Options
# 0   Less than 21 years, 21 - 49 years, 50 - 64 yea...
# 1                                      Female, Male,
# 2   Weight Gain, Hair Problems, Skin Problems, Tir...
# 3   Less than 3 months, 3 - 6 months, 6 - 11 month...
# 4   Less than 5 kgs, 6 - 10 kgs, 11 - 20 kgs, More...
# 5                                           Yes, No,
# 6   21 - 28 days, 28 - 35 days, < 21 days, > 35 da...
# 7               1 to 2, 3 to 4, 5 to 7, More than 7,
# 8   Feeling Cold Often, Observed Swelling (face/fe...
# 9                                           Yes, No,
# 10  Less than 3 months, Less than 5 kgs, 21 - 28 d...
# 11  Yes, Stress, Regular Exercise, Overeating, Dis...
# 12  Yes, Stress, I am a pregnant woman, Family his...
# 13  Yes, Stress, I am a pregnant woman, Diabetes, ...

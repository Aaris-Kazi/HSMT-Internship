# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\aaris\\Desktop\\forinternship\\HSMT-Internship\\chat1.csv')

# %%
df
# Out:
#     Unnamed: 0                                          Questions
# 0            0               Please let me know how old you are.
# 1            1                                     And you are...
# 2            2          Do you relate with any of these symptoms?
# 3            3  As you are experiencing a 'pounding heartbeat'...
# 4            4  Have you had your cholesterol level tested rec...
# 5            5  Did your report mention any of these abnormali...
# 6            6                   Do you have high blood pressure?
# 7            7     Are you on medication for high blood pressure?
# 8            8  Do you smoke or are constantly exposed to pass...
# 9            9  Have you smoked 100 or more cigarettes in your...
# 10          10                              Do you drink alcohol?
# 11          11  Have you experienced any of the following cond...
# 12          12  Has anyone in your family (parents, siblings, ...
# ...

# %%
sf = pd.read_csv('C:\\Users\\aaris\\Desktop\\forinternship\\HSMT-Internship\\chat.csv')

# %%
sf
# Out:
#     Unnamed: 0                                            Options
# 0            0  20 years & less, 21 to 30 years, 31 to 40 year...
# 1            1                              Male, Female, Other,
# 2            2  Pounding heart beat at rest, Episodes of giddi...
# 3            3          Below 80, 80 -100, 101 - 140, Above 140,
# 4            4                                          Yes, No,
# 5            5  High LDL, Low HDL, High Total Cholesterol, Hig...
# 6            6  Yes, I have high BP, No, I've always had norma...
# 7            7                                          Yes, No,
# 8            8           Yes, No, More than 1 year since I quit,
# 9            9                                          Yes, No,
# 10          10  Occasionally, Everyday( > 2 drinks/day), I don...
# 11          11          Heart attack, Stroke, None of the above,
# 12          12  Heart attack, Stroke, Angioplasty/ Stent place...
# ...

# %%
df['Options']= sf['Options'].values

# %%
df.to_csv('chat3.csv')

# %%
df
# Out:
#     Unnamed: 0                                          Questions  \
# 0            0               Please let me know how old you are.
# 1            1                                     And you are...
# 2            2          Do you relate with any of these symptoms?
# 3            3  As you are experiencing a 'pounding heartbeat'...
# 4            4  Have you had your cholesterol level tested rec...
# 5            5  Did your report mention any of these abnormali...
# 6            6                   Do you have high blood pressure?
# 7            7     Are you on medication for high blood pressure?
# 8            8  Do you smoke or are constantly exposed to pass...
# 9            9  Have you smoked 100 or more cigarettes in your...
# 10          10                              Do you drink alcohol?
# 11          11  Have you experienced any of the following cond...
# 12          12  Has anyone in your family (parents, siblings, ...
# ...
